# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun-bhim/Syntax-Error-25/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("BiocManager")
BiocManager::install("AnnotationHub")
BiocManager::install("ensembldb")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.22 (BiocManager 1.30.27), R 4.5.3 (2026-03-11)
#
# Installing package(s) 'BiocVersion', 'AnnotationHub'
#
# also installing the dependencies ‘XVector’, ‘Seqinfo’, ‘png’, ‘Biostrings’, ‘filelock’, ‘Biobase’, ‘IRanges’, ‘KEGGREST’, ‘BiocGenerics’, ‘BiocFileCache’, ‘RSQLite’, ‘AnnotationDbi’, ‘S4Vectors’, ‘BiocBaseUtils’
#
#
# Old packages: 'backports', 'cpp11', 'dplyr', 'ellipsis', 'magrittr', 'nlme',
#   'xtable'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# ...

# %%
library(AnnotationHub)
library(ensembldb)
# Out:
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# Loading required package: BiocFileCache
#
# Loading required package: dbplyr
#
# Loading required package: GenomicRanges
#
# ...

# %%
ah <- AnnotationHub()
edb <- ah[["AH119325"]]
# Out:
# downloading 1 resources
#
# retrieving 1 resource
# loading from cache

# %%
tx <- transcripts(edb, filter = ~ gene_name == "OPN1LW")
tx

write.table(tx,
            file = "OPN1LW_transcripts.tsv",
            sep = "\t",
            row.names = FALSE,
            quote = FALSE)
# Out:
# GRanges object with 3 ranges and 12 metadata columns:
#                   seqnames              ranges strand |           tx_id
#                      <Rle>           <IRanges>  <Rle> |     <character>
#   ENST00000369951        X 154144243-154159032      + | ENST00000369951
#   ENST00000463296        X 154144274-154156397      + | ENST00000463296
#   ENST00000442922        X 154152942-154159023      + | ENST00000442922
#                               tx_biotype tx_cds_seq_start tx_cds_seq_end
#                              <character>        <integer>      <integer>
#   ENST00000369951         protein_coding        154144284      154158926
#   ENST00000463296 protein_coding_CDS_n..             <NA>           <NA>
#   ENST00000442922         protein_coding        154152942      154158926
#                           gene_id tx_support_level     tx_id_version gc_content
#                       <character>        <integer>       <character>  <numeric>
# ...

# %%
pr <- proteins(edb, filter = ~ gene_name == "OPN1LW")
pr

write.table(pr,
            file = "OPN1LW_proteins.tsv",
            sep = "\t",
            row.names = FALSE,
            quote = FALSE)
# Out:
# DataFrame with 2 rows and 4 columns
#             tx_id      protein_id       protein_sequence   gene_name
#       <character>     <character>            <character> <character>
# 1 ENST00000369951 ENSP00000358967 MAQQWSLQRLAGRHPQDSYE..      OPN1LW
# 2 ENST00000442922 ENSP00000402493 ITGLWSLAIISWERWMVVCK..      OPN1LW

# %%
tx_ids <- pr$tx_id
tx_ids

tx_gr <- transcripts(edb, filter = ~ tx_id %in% tx_ids)
tx_gr

mapping_df <- as.data.frame(tx_gr)

write.table(mapping_df,
            file = "OPN1LW_protein_genome_map.tsv",
            sep = "\t",
            row.names = FALSE,
            quote = FALSE)
# Out:
# [1] "ENST00000369951" "ENST00000442922"
# GRanges object with 2 ranges and 11 metadata columns:
#                   seqnames              ranges strand |           tx_id
#                      <Rle>           <IRanges>  <Rle> |     <character>
#   ENST00000369951        X 154144243-154159032      + | ENST00000369951
#   ENST00000442922        X 154152942-154159023      + | ENST00000442922
#                       tx_biotype tx_cds_seq_start tx_cds_seq_end
#                      <character>        <integer>      <integer>
#   ENST00000369951 protein_coding        154144284      154158926
#   ENST00000442922 protein_coding        154152942      154158926
#                           gene_id tx_support_level     tx_id_version gc_content
#                       <character>        <integer>       <character>  <numeric>
#   ENST00000369951 ENSG00000102076                1 ENST00000369951.9    57.0048
#   ENST00000442922 ENSG00000102076                5 ENST00000442922.1    55.5743
# ...
